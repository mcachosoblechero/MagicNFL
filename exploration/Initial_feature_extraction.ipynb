# %% [markdown]
# # Initial Feature Extraction
#
# This notebook extracts features from the different plays and analyzes the correlation between the different plays.
# The following functions are developed during this process:
# - **extract_play_outcome_features**: This function extracts information regarding the outcomes of each play: pocket status, TD, pass complete, etc...
# - **extract_formation_features**: This function analyzes the initial formation, describing the position of the different players
# - **extract_foul_features**: This function extracts foul-related information
# - **extract_injury_features**: This function extracts injury-related information
#
# These functions will be stored inside the folder __feature_extraction__ for future use.
#
# Furthermore, an initial Data Vizualization is performed to understand the correlation between variables.

# %% [markdown]
# # 0. Load libraries and constants

# %%
import os
import re
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.append('../')
from definitions.fouls_def import ignore_fouls

# %%
# Define input parameters
input_path = '../input'

# %% [markdown]
# # 1. Feature Extraction

# %%
plays_data = pd.read_csv(os.path.join(input_path, 'plays.csv'))
plays_data.head(5)
# Out:
#        gameId  playId                                    playDescription  \
# 0  2021090900      97  (13:33) (Shotgun) T.Brady pass incomplete deep...
# 1  2021090900     137  (13:18) (Shotgun) D.Prescott pass deep left to...
# 2  2021090900     187  (12:23) (Shotgun) D.Prescott pass short middle...
# 3  2021090900     282  (9:56) D.Prescott pass incomplete deep left to...
# 4  2021090900     349  (9:46) (Shotgun) D.Prescott pass incomplete sh...
#
#    quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 0        1     3          2             TB           DAL           TB
# 1        1     1         10            DAL            TB          DAL
# 2        1     2          6            DAL            TB          DAL
# 3        1     1         10            DAL            TB           TB
# 4        1     3         15            DAL            TB           TB
#
#    yardlineNumber  ... foulNFLId3  absoluteYardlineNumber  offenseFormation  \
# 0              33  ...        NaN                    43.0           SHOTGUN
# 1               2  ...        NaN                   108.0             EMPTY
# 2              34  ...        NaN                    76.0           SHOTGUN
# 3              39  ...        NaN                    49.0        SINGLEBACK
# 4              44  ...        NaN                    54.0           SHOTGUN
#
#          personnelO  defendersInBox        personnelD  dropBackType  \
# 0  1 RB, 1 TE, 3 WR             6.0  4 DL, 2 LB, 5 DB   TRADITIONAL
# 1  1 RB, 2 TE, 2 WR             6.0  4 DL, 4 LB, 3 DB   TRADITIONAL
# 2  0 RB, 2 TE, 3 WR             6.0  3 DL, 3 LB, 5 DB   TRADITIONAL
# 3  1 RB, 2 TE, 2 WR             6.0  4 DL, 3 LB, 4 DB   TRADITIONAL
# 4  1 RB, 1 TE, 3 WR             7.0  3 DL, 4 LB, 4 DB   TRADITIONAL
#
#   pff_playAction  pff_passCoverage pff_passCoverageType
# 0              0           Cover-1                  Man
# 1              0           Cover-3                 Zone
# 2              0           Cover-3                 Zone
# 3              1           Cover-3                 Zone
# 4              0           Cover-3                 Zone
#
# [5 rows x 32 columns]

# %%
plays_data.columns
# Out:
# Index(['gameId', 'playId', 'playDescription', 'quarter', 'down', 'yardsToGo',
#        'possessionTeam', 'defensiveTeam', 'yardlineSide', 'yardlineNumber',
#        'gameClock', 'preSnapHomeScore', 'preSnapVisitorScore', 'passResult',
#        'penaltyYards', 'prePenaltyPlayResult', 'playResult', 'foulName1',
#        'foulNFLId1', 'foulName2', 'foulNFLId2', 'foulName3', 'foulNFLId3',
#        'absoluteYardlineNumber', 'offenseFormation', 'personnelO',
#        'defendersInBox', 'personnelD', 'dropBackType', 'pff_playAction',
#        'pff_passCoverage', 'pff_passCoverageType'],
#       dtype='object')

# %%
def extract_play_outcome_features(plays_data):

    play_outcome = pd.DataFrame()

    # Play Identifiers
    play_outcome['gameId'] = plays_data.gameId
    play_outcome['playId'] = plays_data.playId
    # Has_pocket_hold - This feature answers the question, was the QB able to pass inside the pocket? 
    # This includes C, I and IN; as in all these plays the QB is able to pass the ball
    play_outcome['has_pocket_hold'] = plays_data.passResult.apply(lambda x : True if (x=='C')|(x=='I')|(x=='IN') else False)
    # was_qb_sacked - Self-explanatory 
    play_outcome['was_qb_sacked'] = plays_data.passResult.apply(lambda x : True if (x=='S') else False)
    # achieved_positive_yards - Self-explanatory, binary result
    play_outcome['achieved_pos_yards'] = plays_data.playResult.apply(lambda x: True if (x>0) else False)
    # gained_yards - Self-explanatory
    play_outcome['gained_yards'] = plays_data.playResult
    # touchdown - Self-explanatory
    play_outcome['touchdown'] = plays_data.playDescription.apply(lambda x: False if re.search('touchdown', x.lower()) == None else True)
    
    return play_outcome

# %%
def extract_number_players_regexp(x, pattern):

    # Match pattern
    match = re.search(pattern, x)

    # If pattern not available, return 0
    if match == None:
        return 0
    # Else, return the number
    else:
        return int(match[0][0])

def extract_formation_features(plays_data):

    play_formation = pd.DataFrame()

    # Play Identifiers
    play_formation['gameId'] = plays_data.gameId
    play_formation['playId'] = plays_data.playId

    # Set of features describing the formation
    # num_XX - # of players on the position
    # Possible positions:
    # RB -> Running Back
    # QB -> Quarterback - Ignore for now, this is not relevant
    # WR -> ???? - Need to check
    # TE -> ???? - Need to check
    # OL -> Offensive Lineman? - Need to check
    play_formation['num_rb'] = plays_data.personnelO.astype(str).apply(extract_number_players_regexp, pattern='\d RB')
    play_formation['num_wr'] = plays_data.personnelO.astype(str).apply(extract_number_players_regexp, pattern='\d WR')
    play_formation['num_te'] = plays_data.personnelO.astype(str).apply(extract_number_players_regexp, pattern='\d TE')
    play_formation['num_ol'] = plays_data.personnelO.astype(str).apply(extract_number_players_regexp, pattern='\d OL')
    # Note - Would we obtain the same result if we check the players position? 

    # Extract the offense formation used
    play_formation['formation'] = plays_data.offenseFormation

    return play_formation

# %%
def determine_foul_side(x):
    
    # Define pattern - Acept teams with either 2 or 3 letters
    pattern = 'penalty on [a-z]{2,3}-[a-z]\.[a-z]*,'

    # Extract valuable fields
    descrip = x.playDescription.lower()
    offense = x.possessionTeam.lower()
    defense = x.defensiveTeam.lower() 

    # Create final variables
    off_foul = 0
    off_penalty = []
    off_players = []
    def_foul = 0
    def_penalty = []
    def_players = []

    matches = re.findall(pattern, descrip)
    if matches!=[]:
        for idx, match in enumerate(matches):
            # Extract team from string
            team = match.split(" ")[-1].split("-")[0]
            player = match.split(" ")[-1].split("-")[1].replace(",","")
            
            # Determine whether it is a valid foul
            foul_number = idx + 1
            foulCol = f"foulName{foul_number}"
            foulName = x[foulCol]
            if foulName in ignore_fouls:
                next

            # Determine which team has committed the foul & store the penalty  
            if team == offense:
                off_foul += 1
                off_penalty.append(x[foulCol])
                off_players.append(player)
            elif team == defense:
                def_foul += 1
                def_penalty.append(x[foulCol])
                def_players.append(player)

            else:
                assert False, "Foul to neither team??"

    return off_foul, off_penalty, off_players, def_foul, def_penalty, def_players

def extract_foul_features(plays_data):

    play_foul = pd.DataFrame()

    # Play Identifiers
    play_foul['gameId'] = plays_data.gameId
    play_foul['playId'] = plays_data.playId

    # How to detect an offensive/defensive foul:
    # 1- The word "Penalty on XX" is found
    # 2- The "possesionTeam"/"defensiveTeam" is equal to XX
    # 3- The foul called should not be ignored
    foul_info = plays_data.apply(determine_foul_side, axis=1)

    # I hate this way of solving this, but I don;t have internet to get a better way
    off_foul = []
    off_penalty = []
    off_players = []
    def_foul = []
    def_penalty = []
    def_players = []
    for record in foul_info:
        off_foul.append(record[0])
        off_penalty.append(record[1])
        off_players.append(record[2])
        def_foul.append(record[3])
        def_penalty.append(record[4])
        def_players.append(record[5])

    # Assign to DataFrame
    play_foul['num_off_foul'] = off_foul
    play_foul['off_penalties'] = off_penalty
    play_foul['off_penalties_players'] = off_players
    play_foul['num_def_foul'] = def_foul 
    play_foul['def_penalties'] = def_penalty
    play_foul['def_penalties_players'] = def_players

    return play_foul
# Out:
#           gameId  playId  num_off_foul                    off_penalties  \
# 21    2021090900    1227             1                       [Taunting]
# 44    2021090900    2298             1              [Offensive Holding]
# 58    2021090900    2915             1              [Offensive Holding]
# 59    2021090900    3014             1  [Illegal Block Above the Waist]
# 83    2021090900    4211             1              [Offensive Holding]
# ...          ...     ...           ...                              ...
# 8475  2021103112    4076             1              [Offensive Holding]
# 8513  2021110100    1942             1          [Intentional Grounding]
# 8519  2021110100    2226             1              [Offensive Holding]
# 8543  2021110100    3796             1                       [Taunting]
# 8548  2021110100    4016             1              [Offensive Holding]
#
#      off_penalties_players  num_def_foul            def_penalties  \
# 21              [r.jensen]             1  [Unnecessary Roughness]
# 44            [c.williams]             0                       []
# 58               [t.wirfs]             0                       []
# 59             [t.pollard]             1               [Tripping]
# 83               [t.smith]             0                       []
# ...                    ...           ...                      ...
# 8475          [c.williams]             0                       []
# 8513           [p.mahomes]             0                       []
# 8519            [n.solder]             0                       []
# 8543             [e.penny]             0                       []
# 8548             [o.brown]             0                       []
#
#      def_penalties_players
# 21             [c.watkins]
# 44                      []
# 58                      []
# 59             [s.barrett]
# 83                      []
# ...                    ...
# 8475                    []
# 8513                    []
# 8519                    []
# 8543                    []
# 8548                    []
#
# [268 rows x 8 columns]

# %%
def determine_injury_side(x):
    
    # Define pattern - Acept teams with either 2 or 3 letters
    pattern = '\. [a-z]{2,3}-[a-z]\..* was injured'

    # Extract valuable fields
    descrip = x.playDescription.lower()
    offense = x.possessionTeam.lower()
    defense = x.defensiveTeam.lower() 

    # Create final variables
    off_injury = 0
    off_players = []
    def_injury = 0
    def_players = []

    matches = re.findall(pattern, descrip)
    if matches!=[]:
        for idx, match in enumerate(matches):

            print(match)

            # Extract team from string
            team = match.split("-")[0].split(" ")[-1]
            player = match.replace(" was injured", "").split("-", 1)[1]

            print(player)

            # Determine which team has an injured player
            if team == offense:
                off_injury += 1
                off_players.append(player)
            elif team == defense:
                def_injury += 1
                def_players.append(player)
            else:
                assert False, "Injury to neither team??"

    return off_injury, off_players, def_injury, def_players

def extract_injury_features(plays_data):

    play_injury = pd.DataFrame()

    # Play Identifiers
    play_injury['gameId'] = plays_data.gameId
    play_injury['playId'] = plays_data.playId

    # How to detect an offensive/defensive injury:
    # 1- The word "XX-<Full Name> was injured during the play" is found
    # 2- The "possesionTeam"/"defensiveTeam" is equal to XX
    injury_info = plays_data.apply(determine_injury_side, axis=1)

    # I hate this way of solving this, but I don;t have internet to get a better way
    off_injury = []
    off_players = []
    def_injury = []
    def_players = []
    for record in injury_info:
        off_injury.append(record[0])
        off_players.append(record[1])
        def_injury.append(record[2])
        def_players.append(record[3])

    # Assign to DataFrame
    play_injury['num_off_injuries'] = off_injury
    play_injury['off_players_injured'] = off_players
    play_injury['num_def_injuries'] = def_injury 
    play_injury['def_players_injured'] = def_players

    return play_injury

plays_injury = extract_injury_features(plays_data)
# Out:
# . tb-s.murphy-bunting was injured
# s.murphy-bunting
# . tb-w.gholston was injured
# w.gholston
# . tb-m.edwards was injured
# m.edwards
# . atl-j.mayfield was injured
# j.mayfield
# . pit-d.johnson was injured
# d.johnson
# . nyj-m.becton was injured
# m.becton
# . car-d.jackson was injured
# d.jackson
# . min-b.breeland was injured
# b.breeland
# . det-t.williams was injured
# t.williams
# . sf-j.verrett was injured
# j.verrett
# . sf-j.ward was injured
# j.ward
# . sf-a.al-shaair was injured
# a.al-shaair
# . sf-d.flannigan-fowles was injured
# d.flannigan-fowles
# . hou-v.hargreaves was injured
# v.hargreaves
# . hou-v.taylor was injured
# v.taylor
# . sea-p.ford was injured
# p.ford
# . sea-c.dunlap was injured
# c.dunlap
# . ten-t.tart was injured during the play. his return is questionable. ten-h.landry was injured
# t.tart during the play. his return is questionable. ten-h.landry
# . ten-o.adeniyi was injured
# o.adeniyi
# . was-r.fitzpatrick was injured
# r.fitzpatrick
# . lac-m.davis was injured
# m.davis
# . cle-a.walker was injured
# a.walker
# . ne-d.harris was injured
# d.harris
# . mia-e.rowe was injured
# e.rowe
# . no-e.mccoy was injured
# e.mccoy
# . den-j.jeudy was injured during the play.  the replay official reviewed the fumble ruling, and the play was reversed. (shotgun) t.bridgewater pass deep left to j.jeudy to nyg 13 for 20 yards (j.bradberry) [l.williams]. den-j.jeudy was injured
# j.jeudy during the play.  the replay official reviewed the fumble ruling, and the play was reversed. (shotgun) t.bridgewater pass deep left to j.jeudy to nyg 13 for 20 yards (j.bradberry) [l.williams]. den-j.jeudy
# . la-d.long was injured
# d.long
# . bal-m.humphrey was injured
# m.humphrey
# . lv-g.mccoy was injured
# g.mccoy
# . nyg-n.gates was injured
# n.gates
# . was-m.ioannidis was injured
# m.ioannidis
# . car-p.elflein was injured
# p.elflein
# . cle-b.mayfield was injured
# b.mayfield
# . cle-m.smith was injured
# m.smith
# . mia-t.tagovailoa was injured
# t.tagovailoa
# . ne-j.herron was injured
# j.herron
# . sf-k.juszczyk was injured
# k.juszczyk
# . lv-c.hayward was injured
# c.hayward
# . lv-d.carr was injured
# d.carr
# . lv-d.perryman was injured
# d.perryman
# . lv-c.hayward was injured
# c.hayward
# . lv-d.leavitt was injured
# d.leavitt
# . atl-s.means was injured
# s.means
# . atl-a.terrell was injured
# a.terrell
# . tb-m.evans was injured
# m.evans
# . dal-a.cooper was injured
# a.cooper
# . sea-b.shell was injured
# b.shell
# . det-i.melifonwu was injured
# i.melifonwu
# . gb-c.sullivan was injured
# c.sullivan
# . car-j.burris was injured
# j.burris
# . car-j.horn was injured
# j.horn
# . was-b.scherff was injured
# b.scherff
# . cle-j.wills was injured
# j.wills
# . bal-d.hayes was injured
# d.hayes
# . bal-d.elliott was injured
# d.elliott
# . lac-t.campbell was injured
# t.campbell
# . no-t.armstead was injured
# t.armstead
# . nyg-b.martinez was injured
# b.martinez
# . atl-m.davidson was injured
# m.davidson
# . pit-k.green was injured
# k.green
# . ten-r.weaver was injured
# r.weaver
# . ten-k.fulton was injured
# k.fulton
# . den-k.hamler was injured
# k.hamler
# . lv-t.mullen was injured
# t.mullen
# . mia-w.fuller was injured
# w.fuller
# . lv-t.mullen was injured
# t.mullen
# . tb-j.dean was injured
# j.dean
# . tb-r.gronkowski was injured
# r.gronkowski
# . tb-g.bernard was injured
# g.bernard
# . sea-j.brooks was injured
# j.brooks
# . sea-t.lockett was injured
# t.lockett
# . sea-d.metcalf was injured
# d.metcalf
# . gb-k.barnes was injured
# k.barnes
# . gb-c.sullivan was injured
# c.sullivan
# . gb-d.adams was injured
# d.adams
# . phi-i.seumalo was injured
# i.seumalo
# . dal-m.parsons was injured
# m.parsons
# . atl-i.oliver was injured
# i.oliver
# . was-c.holcomb was injured
# c.holcomb
# . was-a.gibson was injured
# a.gibson
# . was-t.mclaurin was injured
# t.mclaurin
# . atl-e.harris was injured
# e.harris
# . was-t.mctyer was injured
# t.mctyer
# . det-r.okwara was injured
# r.okwara
# . cle-j.clowney was injured
# j.clowney
# . no-m.callaway was injured
# m.callaway
# . nyj-b.echols was injured
# b.echols
# . ten-j.reynolds was injured
# j.reynolds
# . nyj-j.wilson was injured
# j.wilson
# . ten-t.lewan was injured
# t.lewan
# . nyj-j.franklin-myers was injured
# j.franklin-myers
# . ari-a.hamilton was injured
# a.hamilton
# . sf-j.kinlaw was injured
# j.kinlaw
# . sf-t.williams was injured
# t.williams
# . sea-d.taylor was injured
# d.taylor
# . sea-c.dunlap was injured
# c.dunlap
# . sea-c.dunlap was injured
# c.dunlap
# . den-d.spencer was injured
# d.spencer
# . bal-a.villanueva was injured
# a.villanueva
# . pit-d.bush was injured
# d.bush
# . gb-j.alexander was injured
# j.alexander
# . gb-d.savage was injured
# d.savage
# . pit-k.dotson was injured
# k.dotson
# . ne-j.meyers was injured
# j.meyers
# . ne-j.jones was injured
# j.jones
# . lv-q.jefferson was injured
# q.jefferson
# . phi-d.barnett was injured
# d.barnett
# . cin-j.burrow was injured
# j.burrow
# . cin-j.bates was injured
# j.bates
# . det-q.cephus was injured
# q.cephus
# . den-s.harris was injured
# s.harris
# . den-m.purcell was injured
# m.purcell
# . den-d.jones was injured
# d.jones
# . tb-l.david was injured
# l.david
# . was-s.cosmi was injured
# s.cosmi
# . cle-m.mcdowell was injured
# m.mcdowell
# . cle-a.green was injured
# a.green
# . lac-m.williams was injured
# m.williams
# . cle-m.garrett was injured
# m.garrett
# . lac-d.tranquill was injured
# d.tranquill
# . chi-j.fields was injured
# j.fields
# . chi-g.ifedi was injured
# g.ifedi
# . ari-i.simmons was injured
# i.simmons
# . ari-m.williams was injured
# m.williams
# . nyg-r.williams was injured
# r.williams
# . buf-l.wallace was injured
# l.wallace
# . bal-b.cleveland was injured
# b.cleveland
# . ind-g.stewart was injured
# g.stewart
# . ind-x.rhodes was injured
# x.rhodes
# . tb-r.sherman was injured
# r.sherman
# . bal-p.queen was injured
# p.queen
# . lac-a.ogbongbemiga was injured
# a.ogbongbemiga
# . lac-d.parham was injured
# d.parham
# . min-p.peterson was injured
# p.peterson
# . det-n.williams was injured
# n.williams
# . hou-t.brooks was injured
# t.brooks
# . ind-r.ya-sin was injured
# r.ya-sin
# . ind-t.hilton was injured
# t.hilton
# . la-r.rochell was injured
# r.rochell
# . kc-a.hitchens was injured
# a.hitchens
# . kc-j.fortson was injured
# j.fortson
# . cle-b.mayfield was injured
# b.mayfield
# . cle-k.hunt was injured
# k.hunt
# . lv-c.hayward was injured
# c.hayward
# . lv-b.facyson was injured
# b.facyson
# . ne-j.jones was injured
# j.jones
# . ne-j.bentley was injured
# j.bentley
# . ne-m.judon was injured
# m.judon
# . dal-t.basham was injured
# t.basham
# . ten-c.farley was injured
# c.farley
# . ten-c.jackson was injured
# c.jackson
# . ten-c.jackson was injured
# c.jackson
# . den-v.miller was injured
# v.miller
# . cle-o.beckham was injured
# o.beckham
# . cle-d.ward was injured
# d.ward
# . bal-p.mekari was injured
# p.mekari
# . cin-c.sample was injured
# c.sample
# . was-c.young was injured
# c.young
# . was-d.brown was injured
# d.brown
# . gb-r.douglas was injured
# r.douglas
# . mia-e.roberts was injured
# e.roberts
# . atl-c.ridley was injured
# c.ridley
# . atl-e.harris was injured
# e.harris
# . nyj-z.wilson was injured during the play. his return is questionable. ne-d.mccourty was injured
# z.wilson during the play. his return is questionable. ne-d.mccourty
# . nyj-j.franklin-myers was injured during the play. nyj-b.cashman was injured
# j.franklin-myers during the play. nyj-b.cashman
# . nyj-g.fant was injured
# g.fant
# . car-d.jackson was injured
# d.jackson
# . ten-r.saffold was injured
# r.saffold
# . ten-k.lamm was injured
# k.lamm
# . ten-r.saffold was injured
# r.saffold
# . ten-n.davis was injured
# n.davis
# . kc-p.mahomes was injured
# p.mahomes
# . det-a.parker was injured
# a.parker
# . phi-m.williams was injured
# m.williams
# . lv-d.perryman was injured
# d.perryman
# . tb-j.dean was injured
# j.dean
# . sf-e.moseley was injured
# e.moseley
# . no-a.peat was injured
# a.peat
# . no-c.ringo was injured
# c.ringo
# . sea-m.blair was injured
# m.blair
# . gb-r.tonyan was injured
# r.tonyan
# . gb-h.black was injured
# h.black
# . ari-k.murray was injured
# k.murray
# . car-r.anderson was injured
# r.anderson
# . chi-e.jackson was injured
# e.jackson
# . sf-d.jones was injured
# d.jones
# . sf-f.warner was injured
# f.warner
# . ind-t.lewis was injured
# t.lewis
# . ten-d.cruikshank was injured
# d.cruikshank
# . ind-t.hilton was injured
# t.hilton
# . ten-r.tannehill was injured
# r.tannehill
# . nyj-m.carter ii was injured
# m.carter ii
# . nyj-m.white was injured
# m.white
# . lac-a.samuel was injured
# a.samuel
# . lac-a.samuel was injured
# a.samuel
# . sea-d.taylor was injured
# d.taylor
# . was-c.roullier was injured
# c.roullier
# . den-b.callahan was injured
# b.callahan
# . was-e.flowers was injured
# e.flowers
# . no-j.winston was injured
# j.winston
# . min-b.breeland was injured
# b.breeland
# . min-j.jefferson was injured
# j.jefferson
# . nyg-s.shepard was injured
# s.shepard

# %%
# Perform all feature extractions
plays_outcomes = extract_play_outcome_features(plays_data)
plays_formation = extract_formation_features(plays_data)
plays_fouls = extract_foul_features(plays_data)
plays_injury = extract_injury_features(plays_data)

# %% [markdown]
# # 2. EDA
